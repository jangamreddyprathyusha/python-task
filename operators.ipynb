# %% [markdown]
# arithmetic operators

# %%
x=10
y=20
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x//y)
print(x%y)
print(x**y)
# Out:
# 30
# -10
# 200
# 0.5
# 0
# 10
# 100000000000000000000

# %% [markdown]
# Assignment operator

# %%
x=10
y=5
x+=y
print(x)
x-=y
print(x)
x*=y
print(x)
x/=y
print(x)
x//=y
print(x)
x%=y
print(x)
x**=y
print(x)
# Out:
# 15
# 10
# 50
# 10.0
# 2.0
# 2.0
# 32.0

# %% [markdown]
# #Relational or Comparison

# %%
x=10
y=5
print(x<y)
print(x>y)
print(x<=y)
print(x>=y)
print(x==y)
print(x!=y)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# Bitwise operator

# %%
a=int(input("enter first value="))
b=int(input("enter second value="))
print(a&b)
print(a|b)
print(a^b)
print(~a)
print(a>>b)
print(a<<b)
# Out:
# 0
# 46
# 46
# -35
# 0
# 139264

# %% [markdown]
# strings

# %%
s1="panda"
s2="bala"
s3="siri"
print(s1>s2)
print(s3<s2)
# Out:
# True
# False

# %% [markdown]
# multiple values

# %%
x=20
y=10
z=30
print(x>y<z)
print(x<y>z)
# Out:
# True
# False

# %% [markdown]
# logical operators

# %%
x=12
y=30
z=10
print((x<y) and (y>z))
print((x<y) and (x>z) and (z>y))
print((x<z) or (z>y))
print((x<y) or (x>y) or (z>y))
print((not(x<z)))
# Out:
# True
# False
# False
# True
# True

# %% [markdown]
# #and or xor

# %%
a=10
b=8
print(a&b)
print(a|b)
print(a^b)
# Out:
# 8
# 10
# 2

# %%
n=32
print(n&(n-1)==0)
# Out:
# True

# %% [markdown]
# #swapping two numbers without using 3rd var and a,b=b,a using bits

# %%
a=9
b=7
print("before swapping",'a=',a,'b=',b)
a^=b
b^=a
a^=b
print("after swapping",'a=',a,'b=',b)
# Out:
# before swapping a= 9 b= 7
# after swapping a= 7 b= 9

# %% [markdown]
# Membership operator

# %%
#Not 
# -(a+b) positive
a=10
print(~a)
# +(a-b) Negitive
a=-10
print(~a)
# Out:
# -11
# 9

# %%
#Lift shift
a=10
print(a<<2)
#Right shift
a=10
print(a>>5)
# Out:
# 40
# 0
