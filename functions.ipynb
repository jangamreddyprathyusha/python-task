# %% [markdown]
# user-defined functions

# %% [markdown]
# 1.without para without return

# %%
def add():
   a=10
   b=20
   c=a+b
   print(c)
add()
# Out:
# 30

# %% [markdown]
# 2.with para without return type

# %%
def student(name,roln,marks):
    print(name,roln,marks)
student("prathu",31,80)
# Out:
# prathu 31 80

# %% [markdown]
# 3.without para with return type

# %%
def add():
    c=10+20
    return c
print(add())
# Out:
# 30

# %% [markdown]
# 4.with para with return

# %%
def add(a,b):
    c=a+b
    return c
print(add(10,30))
print(add(10,-8))
# Out:
# 40
# 2

# %%
d={"raju":201,"rani":289,"prathu":87}
def login(username,password):
    if(username in d.keys() and password in d.values()):
        print("login succeccful")
    else:
        print("check your cred")
u=input("enter name:")
p=input("enter password:")
print(login(u,p))
# Out:
# check your cred
# None

# %%
def add(a,b):
    print(a+b)
add(10,b=101)
# Out:
# 111

# %% [markdown]
# factorial using functions

# %%
def factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact *= i
    return fact
num = int(input("Enter a number: "))
print("Factorial =", factorial(num))
# Out:
# Factorial = 120

# %% [markdown]
# prime or not using function

# %%
def is_prime(n):
    count=0
    for i in range(1,n+1):
        if n%i==0:
            count+=1
    return count==2
n=int(input("enter number:"))
if is_prime(n):
    print("prime")
else:
    print("not prime")
# Out:
# not prime

# %% [markdown]
# amstrong using functions

# %%
def is_armstrong(n):
    temp=n
    sum=0
    while n>0:
        rem=n%10
        sum+=rem**3
        n//=10

    return sum==temp
n = int(input("Enter a number: "))

if is_armstrong(n):
    print(n, "is an Armstrong Number")
else:
    print(n, "is not an Armstrong Number")
# Out:
# 153 is an Armstrong Number

# %% [markdown]
# perfect number using function

# %%
def is_perfect(n):
    tot=0
    for i in range(1,n):
        if n%i==0:
            tot+=i
    return tot==n
n=int(input("Enter a number: "))
if is_perfect(n):
    print(n, "is a Perfect Number")
else:
    print(n, "is not a Perfect Number")
# Out:
# 28 is a Perfect Number

# %% [markdown]
# Neon number using function

# %%
def is_neon(n):
    power=n*n
    tot=0
    while power>0:
        temp=power%10
        tot+=temp
        power//= 10
    return tot==n
n=int(input("Enter a number: "))
if is_neon(n):
    print(n, "is a Neon Number")
else:
    print(n, "is not a Neon Number")
# Out:
# 9 is a Neon Number

# %% [markdown]
# strong number using function

# %%
def factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact *= i
    return fact
def is_strong(num):
    temp = num
    total = 0
    while temp > 0:
        digit = temp % 10
        total += factorial(digit)
        temp //= 10
    return total == num
num = int(input("Enter a number: "))
if is_strong(num):
    print(num, "is a Strong Number")
else:
    print(num, "is not a Strong Number")
# Out:
# 145 is a Strong Number

# %% [markdown]
# palindrome using functions

# %%
def is_palindrome(n):
    rem,rev=0,0
    temp=n
    while temp>0:
       rem=temp%10
       rev=rev*10+rem
       temp//=10
    return rev==n
n=int(input("enter number"))
if is_palindrome(n):
    print("palindrome")
else:
    print("not palindrome")
# Out:
# palindrome
