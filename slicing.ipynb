# %% [markdown]
# Atleast 10 different output generate in SLICING

# %%
s = "PYTHONPROGRAM"

print(s[:])
print(s[0:6])
print(s[6:])
print(s[:4])
print(s[-7:])
print(s[::2])
print(s[1::2])
print(s[::-1])
print(s[2:10])
print(s[-5:-1])
# Out:
# PYTHONPROGRAM
# PYTHON
# PROGRAM
# PYTH
# PROGRAM
# PTOPORM
# YHNRGA
# MARGORPNOHTYP
# THONPROG
# OGRA

# %%
l=[10,20,30,40,50]
print(l[:])
print(l[4:])
print(l[1:4:1])
print(l[1:5])
print(l[1:])
print(l[:5])
print(l[-5:-1:1])
print(l[-6:-2])
print(l[:-1])
print(l[-1:])
print(l[:-2])
print(l[-5])
# Out:
# [10, 20, 30, 40, 50]
# [50]
# [20, 30, 40]
# [20, 30, 40, 50]
# [20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40]
# [10, 20, 30]
# [10, 20, 30, 40]
# [50]
# [10, 20, 30]
# 10
